# %% [markdown]
# # 5. Capstone Project: Data Preparation I

# %% [markdown]
# ***
#
# ![headerall](./images/headers/header_all.jpg)
#
# ##  Goals
#
# ### Project:
# In this work, we will first analyze where and when traffic congestion is highest and lowest in New York State. We will then build different machine learning models capable of predicting cab travel times in and around New York City using only variables that can be easily obtained from a smartphone app or a website. We will then compare their performance and explore the possibility of using additional variables such as weather forecasts and holidays to improve the predictive performance of the models.
#
# ### Section:
# In this section, data will be prepared for the next steps, i.e., exploratory data analysis and machine learning model building. First, we will collect and import the necessary datasets. Next, we will review each of these datasets to fully understand the data and its structure, including the different variables available, their format, and their relevance to the project. Finally, we will perform data cleaning and manipulation, as well as feature engineering, and encoding.
#
# The data preparation will be divided into two subsections, the first dedicated to the external datasets (Data Preparation, Part I) and the second to the New York City Taxi Trip data set (Data Preparation, Part II). Finally, external datasets will be merged with the primary one.
#
# ## Data
# ### External Datasets:
# - Weather Forecast: The 2018 NYC weather forecast was collected from the [National Weather Service Forecast Office](https://w2.weather.gov/climate/index.php?wfo=okx) website. Daily measurements were taken from January to December 2018 in Central Park. These measures are given in imperial units and include daily minimum and maximum temperatures, precipitations, snowfall, and snow depth.
#
# - Holidays: The 2018 NYC holidays list was collected from the [Office Holiday](https://www.officeholidays.com/countries/usa/new-york/2021) website. The dataset contains the name, date, and type of holidays for New York.
#
# - Taxi Zones: The NYC Taxi Zones dataset was collected from the [NYC Open Data](https://data.cityofnewyork.us/Transportation/NYC-Taxi-Zones/d3c5-ddgc) website. It contains the pickup and drop-off zones (Location IDs) for the Yellow, Green, and FHV Trip Records. The taxi zones are based on the NYC Department of City Planning’s Neighborhood.
#
# ### Primary Datasets:
#
# - Taxi Trips: The 2018 NYC Taxi Trip dataset was collected from the [Google Big Query](https://console.cloud.google.com/marketplace/product/city-of-new-york/nyc-tlc-trips?project=jovial-monument-300209&folder=&organizationId=) platform. The dataset contains more than 100'000'000 Yellow Taxi Trip records for 2018 and contains an extensive amount of variables including the pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts.

# %% [markdown]
# ***
# ## Table of Content:
#     1. Data Preparation
#         1.1 External Datasets
#             1.1.1 Weather Forecast Dataset
#             1.1.2 Holidays Dataset
#             1.1.3 Taxi Zones Dataset
#         1.2 Primary Dataset
#             1.2.1 Taxi Trips Dataset
#             1.2.2 Taxi Trips Subset
#     2. Exploratory Data Analysis
#         2.1 Primary Dataset
#             2.1.1 Temporal Analysis
#             2.1.2 Spatio-Temporal Analysis
#         2.2 External Datasets
#             2.2.1 Temporal Analysis of Weather Data
#             2.2.2 Temporal Analysis of Holidays Data
#         2.3 Combined Dataset
#             2.3.1 Overall Features Correlation
#     3. Machine Learning Models
#         3.1 Data Preparation
#         3.2 Baselines
#         3.3 Model Training
#             3.3.1 Linear Regression
#             3.3.2 Support Vector Machine
#             3.3.3 Random Forest
#             3.3.4 Gradient Boosted Decision Tree
#         3.4 Final Models Comparison
#     4. Conclusions

# %% [markdown]
# ***
# ## Python Libraries and Magic Commands Import

# %%
# Import python core libraries
import itertools

# Import data processing libraris gpd
import pandas as pd
import geopandas as gpd
import numpy as np

# Import Visualization librairies
import seaborn as sns 
import matplotlib.pyplot as plt
import contextily as ctx

# %%
# Set up magic commands
# %matplotlib inline
# %config Completer.use_jedi = False

# %% [markdown]
# ***
# ## Functions Import

# %%
# Define a function that transform column headers to titles
def to_title(data, sep='_'):
    return [s.replace(sep, ' ').title() for s in data]

# %%
# Define a function that display individual lineplot of selected numerical columns
def plot_lineplot(
    data, variable, columns, colnames, ncols=1, nrows=1, palette="YlGnBu_r"
):

    # Get the color palette
    cpal = itertools.cycle(sns.color_palette(palette, len(columns) + 1))

    # Create a figure with n columns and rows
    fig, axes = plt.subplots(
        sharex=True, nrows=nrows, ncols=ncols, figsize=(20, nrows * 3.75)
    )

    # Flatten axes for 2D figures
    if ncols > 1 or nrows > 1:
        axes = axes.ravel()

    # Generate the plots
    for ax, col, colname, colour in zip(axes, columns, colnames, cpal):
        ax.plot(data[variable], data[col], color=colour)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.spines["left"].set_visible(False)
        ax.yaxis.set_ticks_position("none")
        ax.tick_params(labelsize=14)
        ax.set_ylabel(colname, fontsize=16)
        ax.grid()

    # Adjust the padding between and around subplots
    fig.tight_layout(pad=0.5, w_pad=0.5)
    
    # just align the last column of axes:
    fig.align_ylabels()

    # Display the figure
    plt.show()

# %%
# Define a function that display a barplot 
def plot_barplot(data, x_var, y_var, x_label, y_label):
    # Create a figure with n columns and rows
    fig, ax = plt.subplots(figsize=(20, 5))
        
    # Generate the plots
    ax.bar(data[x_var], data[y_var])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.yaxis.set_ticks_position('none')
    ax.tick_params(labelsize=14)
    ax.set_xlabel(x_label, fontsize=16)
    ax.set_ylabel(y_label, fontsize=16)
    ax.grid()
    
    # Adjust the padding between and around subplots
    fig.tight_layout(pad=0.5, w_pad=0.5)
    
    # Display the figure
    plt.show()

# %%
# Define a function that display individual boxplot of selected numerical columns
def plot_boxplot(data, columns, colnames, ncols=1, nrows=1, palette="YlGnBu_r"):
    # Create a figure with n columns and rows
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 5, nrows * 5))

    # Get the color palette
    cpal = itertools.cycle(sns.color_palette(palette, len(columns) + 1))

    # Flatten axes for 2D figures
    if ncols > 1 or nrows > 1:
        axes = axes.ravel()

    # Generate the plots
    for ax, col, colname, colour in zip(axes, columns, colnames, cpal):
        sns.boxplot(
            y=col,
            data=data,
            ax=ax,
            width=0.35,
            linewidth=1,
            color=colour,
            boxprops=dict(alpha=0.7),
        )
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.spines["left"].set_visible(False)
        ax.yaxis.set_ticks_position("none")
        ax.xaxis.set_ticks([])
        ax.tick_params(labelsize=14)
        ax.set_xlabel(colname, fontsize=14)
        ax.set_ylabel(None)
        ax.set_title(colname, fontsize=16)
        ax.grid()

    # Adjust the padding between and around subplots
    fig.tight_layout(pad=0.5, w_pad=0.5)

    # Display the figure
    plt.show()

# %%
# Define a function that display individual violinplot of selected numerical columns
def plot_violinplot(data, columns, colnames, ncols=1, nrows=1, palette="YlGnBu_r"):

    # Get the color palette
    cpal = itertools.cycle(sns.color_palette(palette, len(columns)+1))

    # Create a figure with n columns and rows
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 5, nrows * 5))

    # Flatten axes for 2D figures
    if ncols > 1 or nrows > 1:
        axes = axes.ravel()

    # Generate the plots
    for ax, col, colname in zip(axes, columns, colnames):
        violin_plot = ax.violinplot(data[col])

        # Change color of the violin plot
        for pc, color in zip(violin_plot["bodies"], cpal):
            pc.set_facecolor(color)
            pc.set_edgecolor(color)

        violin_plot["cbars"].set_edgecolor("black")
        violin_plot["cmins"].set_edgecolor("black")
        violin_plot["cmaxes"].set_edgecolor("black")

        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.spines["left"].set_visible(False)
        ax.yaxis.set_ticks_position("none")
        ax.tick_params(labelsize=14)
        ax.set_title(colname, fontsize=16)
        ax.grid()

    # Adjust the padding between and around subplots
    fig.tight_layout(pad=0.5, w_pad=0.5)

    # Display the figure
    plt.show()

# %% [markdown]
# ***
# # 1. Data Preparation

# %% [markdown]
# ## 1.1.1 Data Preparation: Weather Forecasts Dataset
#
# ## Goals:
#
# Explore the 2018 NYC Weather Forecasts dataset and perform data cleaning and manipulation, as well as feature engineering and encoding where necessary.
#
# ## Code:

# %%
# Open the 2018 weather forecast data set
weather_df = pd.read_csv(r"data/raw/weather.csv", parse_dates=["Date"])

# Rename the date column
weather_df.rename({"Date": "date"}, axis=1, inplace=True)

# Dispaly the first five rows of the data frame
weather_df.head()
# Out:
#         date  max_temp  min_temp  avg_temp  dep_temp  hdd  cdd  prec new_snow  \
# 0 2018-01-01        19         7      13.0     -22.2   52    0     0        0
# 1 2018-01-02        26        13      19.5     -15.5   45    0     0        0
# 2 2018-01-03        30        16      23.0     -11.8   42    0     0        0
# 3 2018-01-04        29        19      24.0     -10.7   41    0  0.76      9.8
# 4 2018-01-05        19         9      14.0     -20.5   51    0     0        0
#
#   snow_depth
# 0          T
# 1          0
# 2          T
# 3          1
# 4          7

# %% [markdown]
# ### Weather Forecasts Dataset: Data Cleaning
# Before we proceed with feature engineering, binning and encoding, we first have to check if the data needs cleaning.

# %%
# Display a quick description of the data frame
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        365 non-null    datetime64[ns]
#  1   max_temp    365 non-null    int64
#  2   min_temp    365 non-null    int64
#  3   avg_temp    365 non-null    float64
#  4   dep_temp    365 non-null    float64
#  5   hdd         365 non-null    int64
#  6   cdd         365 non-null    int64
#  7   prec        365 non-null    object
#  8   new_snow    365 non-null    object
#  9   snow_depth  365 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 28.6+ KB

# %% [markdown]
# **Notes:** the dataset contains 0 null values. However, the prec, new_snow, and snow_depth columns contain objects or strings, but should only contain numbers (i.e., floats or integers). Getting a list of the columns' unique values will help us identify the problematic entries.

# %%
# Display the unique vlaues from the snow_depth column
print("snow_depth:", weather_df["snow_depth"].unique())

# Display the unique values from the new_snow column
print("new_snow:", weather_df["new_snow"].unique())

# Display the unique values from the prec column
print("prec:", weather_df["prec"].unique())
# Out:
# snow_depth: ['T' '0' '1' '7' '6' '5' '4' '3' '2' '8']
# new_snow: ['0' '9.8' 'T' '0.4' '0.1' '0.9' '0.5' '4.4' '3.2' '8.2' '0.2' '5.5' '6.4']
# prec: ['0' '0.76' '0.01' '0.54' '0.05' '0.19' '0.3' '0.21' 'T' '0.11' '0.18'
#  '0.96' '0.85' '0.58' '1.21' '0.08' '0.16' '0.09' '0.52' '0.04' '0.06'
#  '0.17' '0.73' '0.38' '1.86' '1.41' '0.28' '0.99' '0.03' '0.59' '0.26'
#  '0.47' '2.82' '0.15' '0.95' '0.1' '0.02' '0.25' '0.22' '0.34' '0.65'
#  '0.29' '0.44' '0.27' '0.07' '1.36' '0.23' '0.71' '0.36' '0.64' '2.24'
#  '0.63' '1.06' '0.37' '0.51' '0.24' '0.74' '0.61' '2.9' '0.66' '0.79'
#  '1.04' '0.72' '0.45' '0.93' '0.13' '1.19' '1.95' '0.77' '0.69' '0.84'
#  '0.43' '1.27' '0.68' '1.16' '0.31' '0.97' '0.81' '0.14' '1.43' '1.61'
#  '0.12' '1.15' '1.02']

# %% [markdown]
# **Obsverations:** the snpw_depth, new_snow, and perc columns may contain the T character. According to the National Weather Service Forecast Office, this character stands for trace amounts. Hence we will replace this value with 0 and convert the content of these columns to float. Additionally, we will also get rid of a few columns containing data not needed to train our future models.

# %%
# Replace Ts by 0
weather_df.replace('T', 0, inplace = True)

# Gather columns to be convert to float16
float_columns = ['avg_temp', 'prec', 'new_snow', 'snow_depth']

# Convert string columns to float
weather_df[float_columns] = weather_df[float_columns].astype(float)

# Round numerical columns to one decimals
weather_df = weather_df.round(1)

# Drop non-essential columns
weather_df = weather_df[['date', 'avg_temp', 'prec', 'new_snow', 'snow_depth']]

# Display a quick description of the data frame
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        365 non-null    datetime64[ns]
#  1   avg_temp    365 non-null    float64
#  2   prec        365 non-null    float64
#  3   new_snow    365 non-null    float64
#  4   snow_depth  365 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 14.4 KB

# %% [markdown]
# **Notes:** the T characters were correctly converted to zeros and the columns to float.

# %%
# Display some descriptive statistics
weather_df.describe()
# Out:
#          avg_temp        prec    new_snow  snow_depth
# count  365.000000  365.000000  365.000000  365.000000
# mean    55.953425    0.177534    0.108493    0.178082
# std     17.724324    0.401699    0.846881    0.933834
# min      9.500000    0.000000    0.000000    0.000000
# 25%     41.000000    0.000000    0.000000    0.000000
# 50%     54.000000    0.000000    0.000000    0.000000
# 75%     73.000000    0.100000    0.000000    0.000000
# max     87.500000    2.900000    9.800000    8.000000

# %% [markdown]
# **Notes:** numerical values such as temperature, precipitation and snow depth are given in imperial units. Converting them to metric units is not strictly necessary but can help spot uncommon and outlying values. We will thus convert temperatures to degrees Celsius and depths to centimeters.

# %%
# Convert temperature from fahrenheit to celcius
weather_df['avg_temp'] = (weather_df['avg_temp'] - 32) / 1.8

# Convert inches of snow to centimeters
weather_df['new_snow'] = weather_df['new_snow'] * 2.54

# Display some descriptive statistics
weather_df.describe()
# Out:
#          avg_temp        prec    new_snow  snow_depth
# count  365.000000  365.000000  365.000000  365.000000
# mean    13.307458    0.177534    0.275573    0.178082
# std      9.846847    0.401699    2.151078    0.933834
# min    -12.500000    0.000000    0.000000    0.000000
# 25%      5.000000    0.000000    0.000000    0.000000
# 50%     12.222222    0.000000    0.000000    0.000000
# 75%     22.777778    0.100000    0.000000    0.000000
# max     30.833333    2.900000   24.892000    8.000000

# %% [markdown]
# **Notes:** the numerical columns have been correctly converted to metric units. Some values are extreme, especially for new snowfall, but none appear to be wrong.

# %%
# Define the numerical columns
weather_cols = ['avg_temp',	'prec', 'new_snow', 'snow_depth']

# Define the name sof the columns
weather_colnames = ['Average Temp. (C)', 'Precipitations (cm)', 'New Snow (cm)', 'Snow Depth (cm)']

# Display boxplots of numerical columns
plot_boxplot(weather_df, weather_cols, weather_colnames, ncols=4)

# %%
# Display violinplots of numerical columns
plot_violinplot(weather_df, weather_cols, weather_colnames, ncols=4)

# %%
# Display lineplots of numerical columns
plot_lineplot(weather_df, 'date', weather_cols, weather_colnames, nrows=4)

# %% [markdown]
# **Notes:** The weather dataset contains outliers but no incorrect values. These outliers will not be removed because they are simply natural events that occur less frequently. Precipitation and snowfall are less frequent events with values mostly around zero. Snowfall usually occurs only during the cold season, from October to March, while rainy days can occur at any time of the year, but with peaks of varying intensity depending on the season. Temperatures follow a bimodal distribution with a peak around 5 degrees and another around 25 degrees, corresponding to the average summer and winter temperatures. As for the other variables, they present right-angle distributions.

# %% [markdown]
# ### Weather Forecasts Dataset: Feature Binning
#
# Binning continuous variables could improve some model performance by introducing non-linearity. Therefore, we will group the values of the weather variables according to their intensity level, and each level will be adjusted to contain a sufficient number of data points. The lowest level (level 0) will correspond to no weather event, while the highest level (level 3 or 4) will correspond to the highest intensity of a weather event.

# %%
# Partition average temperatures into 4 bins
weather_df["avg_temp_lvl"] = pd.cut(
    weather_df["avg_temp"],
    bins=4,
    labels=np.arange(4),
    right=True,
)

# Partition precipitations into 4 bins
weather_df["prec_lvl"] = pd.cut(
    weather_df["prec"],
    bins=[-np.inf, 0, 1, 2, 3],
    labels=np.arange(4),
    right=True,
)

# Partition new snows into 3 bins
weather_df["new_snow_lvl"] = pd.cut(
    weather_df["new_snow"],
    bins=[-np.inf, 0, 5, 15, 25],
    labels=np.arange(4),
    right=True,
)

# Partition snow depths into 3 bins
weather_df["snow_depth_lvl"] = pd.cut(
    weather_df["snow_depth"],
    bins=[-np.inf, 0, 4, 8],
    labels=np.arange(3),
    right=True,
)

# Convert categorical variables to numeric values
weather_df[["avg_temp_lvl", "prec_lvl", "new_snow_lvl", "snow_depth_lvl"]] = weather_df[
    ["avg_temp_lvl", "prec_lvl", "new_snow_lvl", "snow_depth_lvl"]
].apply(pd.to_numeric)

# Display the first five rows of the data frame
weather_df.head()
# Out:
#         date   avg_temp  prec  new_snow  snow_depth  avg_temp_lvl  prec_lvl  \
# 0 2018-01-01 -10.555556   0.0     0.000         0.0             0         0
# 1 2018-01-02  -6.944444   0.0     0.000         0.0             0         0
# 2 2018-01-03  -5.000000   0.0     0.000         0.0             0         0
# 3 2018-01-04  -4.444444   0.8    24.892         1.0             0         1
# 4 2018-01-05 -10.000000   0.0     0.000         7.0             0         0
#
#    new_snow_lvl  snow_depth_lvl
# 0             0               0
# 1             0               0
# 2             0               0
# 3             3               1
# 4             0               2

# %% [markdown]
# ### Weather Forecasts Dataset: Preliminary Exploratory Data Analysis

# %%
# Define the numerical columns
weather_cols = ["avg_temp_lvl", "prec_lvl", "new_snow_lvl", "snow_depth_lvl"]

# Define the name sof the columns
weather_colnames = [
    "Average Temp. Levels (C)",
    "Precipitation Levels (cm)",
    "New Snow Levels (cm)",
    "Snow Depth Levels(cm)",
]

# Display lineplots of numerical columns
plot_lineplot(weather_df, "date", weather_cols, weather_colnames, nrows=4)

# %% [markdown]
# **Note:** General trends are still visible after the binning of continuous variables. As we have seen before, snowfall is mainly observed in winter and during the off-season, while rainy days are much more frequent and present all year round. High temperatures are mainly observed in summer and are around 25 degrees Celsius, while low temperatures are mainly observed in winter with an average of about 5 degrees. Finally, the snow depth remains high for several days when the snowfall has been exceptionally heavy in the previous days.

# %% [markdown]
# ## 1.2 Data Preparation: Holidays Dataset
#
# ## Goals:
#
# Combine and explore the 2018 NYC Holidays datasets and perform data cleaning and manipulation, as well as feature engineering, binning and encoding where necessary.
#
# ## Code:

# %%
# Open the 2018 school holiday data set
school_holidays_df = pd.read_csv(r'data/raw/school_holidays.csv')

# Display the first five rows of the data frame
school_holidays_df.head()
# Out:
#      Month  Day                   Holiday Name
# 0  January   15   Dr Martin Luther King Jr day
# 1    March   30                  Spring recess
# 2    March    1                  Spring recess
# 3    March    2                  Spring recess
# 4    March    3                  Spring recess

# %% [markdown]
# ### Holidays Dataset: Data Cleaning
# Before we proceed with feature engineering, binning and encoding, we first have to check if the data needs cleaning.

# %%
# Display a quick description of the data frame
school_holidays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month         27 non-null     object
#  1   Day           27 non-null     int64
#  2   Holiday Name  27 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 776.0+ bytes

# %% [markdown]
# **Notes:** The data frame contains 27 rows and three columns, including the month of the year, the day of the month, and the name of the holiday. There are no missing values. However, we will need to make some changes to this dataset.

# %%
# Get the 2018 official holiday in NYC 
official_holidays_df = pd.read_csv(r'data/raw/official_holidays.csv')

# Display the first five rows of the data frame
official_holidays_df.head()
# Out:
#       Day    Date                      Holiday Name                  Type  \
# 0  Monday   1-Jan                    New Year's Day       Federal Holiday
# 1  Monday  15-Jan        Martin Luther King Jr. Day       Federal Holiday
# 2  Monday  12-Feb                Lincoln's Birthday    Government Holiday
# 3  Monday  19-Feb  Washington's Birthday (Observed)       Federal Holiday
# 4  Sunday  13-May                      Mother's Day  Not A Public Holiday
#
#                                      Comments
# 0                                         NaN
# 1                       3rd Monday in January
# 2  Connecticut, Illinois, Missouri, New York.
# 3                      3rd Monday in February
# 4     2nd Sunday in May. Not a public holiday

# %%
# Display a quick description of the data frame
official_holidays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day           16 non-null     object
#  1   Date          16 non-null     object
#  2   Holiday Name  16 non-null     object
#  3   Type          16 non-null     object
#  4   Comments      12 non-null     object
# dtypes: object(5)
# memory usage: 768.0+ bytes

# %% [markdown]
# **Notes:** The data set contains 16 rows and five columns, including day of week, date, name, and vacation type. There are four missing values in the comment columns. However, the comments column does not contain any relevant information and will be removed later.

# %% [markdown]
# ### Holidays Dataset: Feature Engineering
#
# **School Holidays Dataset:**
#
# First, we will use the month of the year and the day of the month to create a date column. Next, we'll add a column indicating the type of holiday, which in this case is a school holiday. Finally, we'll drop most of the columns, except for the date and holiday type, as these are the only ones that can provide information to help train our models.
#
# **Official Holiday Dataset:**
#
# As with the school vacation dataset, we will first use the month of the year and day of the month contained in the date column to create a complete date. Finally, we'll drop most of the columns, except for the date and holiday type.
#
# Once both datasets are processed, we will combine them into a single data frame.

# %%
# Add a date column from the year, month and day
school_holidays_df["Date"] = school_holidays_df.agg(
    lambda x: f"2018-{x['Month']}-{x['Day']}", axis=1
)

# Convert the date from string to datetime
school_holidays_df["holiday_date"] = pd.to_datetime(
    school_holidays_df["Date"], format="%Y-%B-%d"
)

# Add a column containin the type of holidays
school_holidays_df["holiday_type"] = "School Holiday"

# Drop non-essential columns
school_holidays_df = school_holidays_df[["holiday_date", "holiday_type"]]

# Display the first five rows of the data frame
school_holidays_df.head()
# Out:
#   holiday_date    holiday_type
# 0   2018-01-15  School Holiday
# 1   2018-03-30  School Holiday
# 2   2018-03-01  School Holiday
# 3   2018-03-02  School Holiday
# 4   2018-03-03  School Holiday

# %% [markdown]
# **Notes:** the dates were correctly transformed into a Year-Month-Day format. The school holidays data frame has been correctly formated and will later be merged with the official holidays. We will then process the official holidays data set.

# %%
# Add the missing year in the date column
official_holidays_df['Date'] = official_holidays_df['Date'] + '-2018'

# Convert the date from string to datetime
official_holidays_df['Date'] = pd.to_datetime(official_holidays_df['Date'])

# Drop non-essential columns
official_holidays_df = official_holidays_df[['Date', 'Type']]

# Rename columns to fit their content
official_holidays_df.rename({'Date':'holiday_date', 'Type':'holiday_type'}, axis=1, inplace=True)

# Display the first five rows of the data frame
official_holidays_df.head()
# Out:
#   holiday_date          holiday_type
# 0   2018-01-01       Federal Holiday
# 1   2018-01-15       Federal Holiday
# 2   2018-02-12    Government Holiday
# 3   2018-02-19       Federal Holiday
# 4   2018-05-13  Not A Public Holiday

# %% [markdown]
# **Notes:** the dates were correctly transformed into a Year-Month-Day format. The official holidays data frame has been correctly formated and can now be merged with the school holidays.

# %%
# Merged the school and offical holidays data frame
holidays_df = school_holidays_df.append(official_holidays_df, ignore_index=True)

# Sort the data frame by date
holidays_df.sort_values('holiday_date', inplace=True)

# Display the first five rows of the data frame
holidays_df.head()
# Out:
# C:\Users\tstricker\AppData\Local\Temp\ipykernel_6480\2046956278.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   holidays_df = school_holidays_df.append(official_holidays_df, ignore_index=True)
#    holiday_date        holiday_type
# 27   2018-01-01     Federal Holiday
# 0    2018-01-15      School Holiday
# 28   2018-01-15     Federal Holiday
# 29   2018-02-12  Government Holiday
# 30   2018-02-19     Federal Holiday

# %% [markdown]
# **Note:** the official and school holidays data frames we correctly combined. The final step is to add an additional column to the data frame that will contain ones to indicate that these dates are not normal days.

# %%
#  Add a column containing 1 to indicates that these dates corresponds to holidays
holidays_df['holiday'] = 1

# Display the first five rows of the data frame
holidays_df.head()
# Out:
#    holiday_date        holiday_type  holiday
# 27   2018-01-01     Federal Holiday        1
# 0    2018-01-15      School Holiday        1
# 28   2018-01-15     Federal Holiday        1
# 29   2018-02-12  Government Holiday        1
# 30   2018-02-19     Federal Holiday        1

# %% [markdown]
# ### Holidays Dataset: Feature Encoding
#
# The holiday type column contains strings that we will have to transform into numeric values, as most machine learning algorithms cannot handle non-numeric variables. There are four different types of holidays, namely federal holidays, government holidays, school holidays, and non-public holidays. We will use ordinal encoding to transform the categorical variable into numeric values, while ensuring that the holidays are ranked by national importance. Thus, federal holidays will be assigned the highest rank and non-public holidays the lowest.

# %%
# Encode holiday types according to their national importance
holidays_df["holiday_type"] = holidays_df["holiday_type"].replace(
    {
        "Federal Holiday": 3,
        "Government Holiday": 2,
        "School Holiday": 1,
        "Not A Public Holiday": 0,
    }
)

# Display the first five rows of the data frame
holidays_df.head()
# Out:
#    holiday_date  holiday_type  holiday
# 27   2018-01-01             3        1
# 0    2018-01-15             1        1
# 28   2018-01-15             3        1
# 29   2018-02-12             2        1
# 30   2018-02-19             3        1

# %% [markdown]
# **Notes:** some days can be both a school and an official holiday. In this case, the holiday with the higher rank will take precedence.

# %%
# Sort the data frame by date
holidays_df.sort_values(['holiday_date', 'holiday_type'], inplace=True)

# Discard duplicated holidays while keeping the highest holidays type
holidays_df.drop_duplicates('holiday_date', keep='last', inplace=True)

# Display the first five rows of the data frame
holidays_df.head()
# Out:
#    holiday_date  holiday_type  holiday
# 27   2018-01-01             3        1
# 28   2018-01-15             3        1
# 29   2018-02-12             2        1
# 30   2018-02-19             3        1
# 2    2018-03-01             1        1

# %% [markdown]
# **Notes:** the holiday dataset is now ready to be used and explored.

# %% [markdown]
# ### Holidays Dataset: Preliminary Exploratory Data Analysis

# %%
# Generate dates from the 1st of January to the 31st of December 2018
date_range = pd.date_range(start="2018-01-01", end="2018-12-31")

# Create an empty data frame containin the dates
year_holidays_df = pd.DataFrame({"date": date_range})

# Merge the year holidays data frame with the holiday one
year_holidays_df = year_holidays_df.merge(
    holidays_df,
    how="left",
    left_on="date",
    right_on="holiday_date",
    suffixes=(None, None),
)

# Discard uncessary columns
year_holidays_df = year_holidays_df[["date", "holiday"]]

# Fill NaN from the holiday column with zeros
year_holidays_df = year_holidays_df.fillna(0)

# Display the first five rows of the data frame
year_holidays_df.head()
# Out:
#         date  holiday
# 0 2018-01-01      1.0
# 1 2018-01-02      0.0
# 2 2018-01-03      0.0
# 3 2018-01-04      0.0
# 4 2018-01-05      0.0

# %%
# Compute the sum of monthly holidays
year_holidays_df_gp = (
    year_holidays_df.groupby(pd.Grouper(key="date", freq="M")).sum().reset_index()
)

# Add a month column to the data frame
year_holidays_df_gp["month"] = year_holidays_df_gp["date"].dt.month

# Display a barplot of the number of monthly holidays
plot_barplot(
    year_holidays_df_gp, "month", "holiday", "Month of Year", "Number of Vacation Days"
)

# %% [markdown]
# **Observations**: March and December are the two months with the highest number of holidays. We will see later if the number of monthly vacations can affect traffic in NYC.

# %% [markdown]
# ## 1.1.3 Data Preparation: Zones Dataset
# ### Goals:
# Explore the NYC Taxi Zones dataset and perform data cleaning and manipulation, as well as feature engineering, binning and encoding where necessary.
# ### Code:

# %%
# Import taxi zone data set
# zones_df = gpd.read_file(r"data/raw/zones.geojson").to_crs(epsg=3857)
zones_df = gpd.read_file(r"data/raw/zones.geojson").to_crs(epsg=3857)

# Display the first five rows of the data frame
zones_df.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((-8258175.509 4967457.200, -8258179.5...
# 1         Queens  MULTIPOLYGON (((-8217980.649 4959237.189, -821...
# 2          Bronx  POLYGON ((-8220713.532 4993383.076, -8220638.4...
# 3      Manhattan  POLYGON ((-8234500.209 4971984.014, -8234502.1...
# 4  Staten Island  POLYGON ((-8257036.153 4948033.072, -8256954.6...

# %% [markdown]
# ### Taxi Zones Dataset: Data Cleaning
#
# Before we proceed with feature engineering, binning and encoding, we first have to check if the data needs cleaning.

# %%
# Display a quick description of the data frame
zones_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int64
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int64
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(2)
# memory usage: 14.5+ KB

# %% [markdown]
# The dataset contains 263 rows and seven columns, one for a unique identifier, one for the name of the zone, and one for the name of the borough in which it is located. The remaining three columns contain the length, area, and geospatial coordinates of the zone boundaries. The dataset does not contain any missing values, but does it contains duplicated entries?

# %%
# Check the data frame for duplicated entries
zones_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Notes:** The dataset does not contain duplicate entries, but it may still contain duplicate IDs.

# %%
# Display the number of unique values in each column of the data frame
zones_df.nunique()
# Out:
# OBJECTID      263
# Shape_Leng    263
# Shape_Area    263
# zone          260
# LocationID    260
# borough         6
# geometry      263
# dtype: int64

# %% [markdown]
# **Notes:** the zone and LocationId columns contain duplicated values.

# %%
# Check for duplicated LocationID
zones_df[zones_df.LocationID.duplicated()].head()
# Out:
#      OBJECTID  Shape_Leng  Shape_Area  \
# 56         57    0.019271    0.000018
# 103       104    0.021221    0.000012
# 104       105    0.077425    0.000369
#
#                                               zone  LocationID    borough  \
# 56                                          Corona          56     Queens
# 103  Governor's Island/Ellis Island/Liberty Island         103  Manhattan
# 104  Governor's Island/Ellis Island/Liberty Island         103  Manhattan
#
#                                               geometry
# 56   POLYGON ((-8221090.346 4975513.240, -8221437.0...
# 103  POLYGON ((-8242089.558 4968322.652, -8242034.1...
# 104  POLYGON ((-8239506.632 4967214.503, -8239357.0...

# %% [markdown]
# **Notes:** three duplicate location IDs were found. These places have different shapes but correspond to the same area. Therefore we will not delete these duplicate IDs.

# %% [markdown]
# ### Taxi Zones Dataset: Feature Engineering
#
# The location identifiers do not provide any information about the location of the zone in New York City, as each numeric value was randomly assigned to a zone. Adding geospatial coordinates could help our models find a relationship between the position of the zone and the target variable. We will create two new features containing the x and y coordinates of each zone's centroid. We will then repeate this process for boroughs, for a total of four new features. Lastly, we will create another variable, called BoroughID, which will contain a unique numeric identifier for each borough. The locationID and boroughID will ultimately be removed from the datasets before training to prevent models taking these variables as ordinal values.

# %%
# Create a new column containing the centroid of the zones
zones_centroid = zones_df["geometry"].centroid

# Create a new column containing the y coordinate of the zones' centroid
zones_df["zone_latitude"] = zones_centroid.y

# Create a new column containing the x coordinate of the zones' centroid
zones_df["zone_longitude"] = zones_centroid.x

# Display the first five rows of the data frame
zones_df.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((-8258175.509 4967457.200, -8258179.5...
# 1         Queens  MULTIPOLYGON (((-8217980.649 4959237.189, -821...
# 2          Bronx  POLYGON ((-8220713.532 4993383.076, -8220638.4...
# 3      Manhattan  POLYGON ((-8234500.209 4971984.014, -8234502.1...
# 4  Staten Island  POLYGON ((-8257036.153 4948033.072, -8256954.6...
#
#    zone_latitude  zone_longitude
# 0   4.966993e+06   -8.257012e+06
# 1   4.955975e+06   -8.218863e+06
# ...

# %%
# Get a list of unique boroughs
boroughs = zones_df["borough"].unique()

# Create a new column containing boroughs id
zones_df["BoroughID"] = zones_df["borough"].map(
    dict(zip(boroughs, range(0, len(boroughs))))
)

# Display the first five rows of the data frame
zones_df.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((-8258175.509 4967457.200, -8258179.5...
# 1         Queens  MULTIPOLYGON (((-8217980.649 4959237.189, -821...
# 2          Bronx  POLYGON ((-8220713.532 4993383.076, -8220638.4...
# 3      Manhattan  POLYGON ((-8234500.209 4971984.014, -8234502.1...
# 4  Staten Island  POLYGON ((-8257036.153 4948033.072, -8256954.6...
#
#    zone_latitude  zone_longitude  BoroughID
# 0   4.966993e+06   -8.257012e+06          0
# ...

# %%
# Merge zones into boroughs
borough_df = zones_df.dissolve(by="borough")

# Create a new column containing the centroid of the boroughs
borough_df["borough_centroid"] = borough_df.centroid

# Create a new column containing the y coordinate of the boroughs' centroid
borough_df["borough_latitude"] = borough_df["borough_centroid"].y

# Create a new column containing the x coordinate of the boroughs' centroid
borough_df["borough_longitude"] = borough_df["borough_centroid"].x

# Add the borough data to the zones dataset
zones_df = pd.merge(
    zones_df,
    borough_df[["BoroughID", "borough_latitude", "borough_longitude"]],
    how="left",
    on="BoroughID",
)

# Display the first five rows of the data frame
zones_df.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((-8258175.509 4967457.200, -8258179.5...
# 1         Queens  MULTIPOLYGON (((-8217980.649 4959237.189, -821...
# 2          Bronx  POLYGON ((-8220713.532 4993383.076, -8220638.4...
# 3      Manhattan  POLYGON ((-8234500.209 4971984.014, -8234502.1...
# 4  Staten Island  POLYGON ((-8257036.153 4948033.072, -8256954.6...
#
#    zone_latitude  zone_longitude  BoroughID  borough_latitude  \
# ...

# %% [markdown]
# ### Taxi Zones Dataset: Preliminary Exploratory Data Analysis

# %%
# Creat a figure with one row and one column
fig, axe = plt.subplots(figsize=(10, 10))

# Generate the map
zones_df.plot(
    column="borough",
    ax=axe,
    alpha=0.33,
    cmap="Spectral",
    edgecolor="k",
    legend=True
)


# Add a base map of New York City
ctx.add_basemap(axe, source=ctx.providers.Stamen.TonerLite)

# Define the title of the map
axe.set_title("New York City Boroughs", fontsize=16)

# Remove axes
axe.set_axis_off()

# Display the plot
plt.show()

# %% [markdown]
# **Notes:** New York City is made up of 260 locations or zones, which are divided into six boroughs.

# %%
# Create a figure with one row and one column
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 20))

# Generate the map
for ax, borough in zip(axes.ravel(), zones_df["borough"].unique()):
    zones_borough = zones_df.loc[zones_df.borough == borough]
    zones_borough.plot(
        column="zone", cmap="Spectral", ax=ax, alpha=0.33, edgecolor="grey"
    )
    ax.set_title(f"{borough}: {len(zones_borough.zone.unique())} zones", fontsize=16)
    ax.set_axis_off()

    # Add a base map of New York City
    ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)

# Define the title of the plot
fig.suptitle("New York City Zones", fontsize=20)

# Adjust the padding between and around subplots
fig.tight_layout(pad=0.5, w_pad=0.5)

# Display the figure
plt.show()

# %% [markdown]
# **Notes:**  Manhattan has more than 60 different zones, but compared to Brooklyn and Queens, each zone is smaller in size.

# %% [markdown]
# ***
# ## Data Export

# %%
# Export the weather forecasts dataset
weather_df.to_pickle(r"data/processed/weather.pickle")

# Export the holidays dataset
holidays_df.to_pickle(r"data/processed/holidays.pickle")

# Export the zones dataset
zones_df.to_pickle(r"data/processed/zones.pickle")
